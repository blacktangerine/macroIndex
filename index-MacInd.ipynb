# %% [markdown]
# ~~~
# 이준상, 마지막 업데이트 20230226
# ~~~

# %% [markdown]
# # [경제지표의 이해와 분석](./index.html)

# %% [markdown]
# ## 1장 [국민소득통계(국민계정)](./1장-국민소득통계.html)
#
#
# | 구분 |통계명|내용|
# |:---|:---|:---|
# |국내총생산|경제활동별 GDP|농림어업, 광업, 전기$\cdot$가스$\cdot$수도사업,건설업, 서비스업|
# |   |GDP에 대한 지출|최종소비지출, 총자본형성, 재화와 서비스의 수출, (공제)재화와서비스의 수입|
# |   |GDP 디플레이터|경제활동별 GDP 디플레이터, 지출항목별 GDP 디플레이터|
# |   |GDP에 대한 성장 기여도|경제활동별 성장기여도, 지출항목별 성장기여도|
# |기타 국민소득 관련 지표|실질 국내총소득(GDI)|실질GDP+교역조건 변화에 따른 실질 무역 손익|
# |   |국민총소득(GNI)|GDI+국외순수취요소소득|
# |   |국민순소득(NNI)|GNI-고정자본소모|
# |   |총저축|GNDI-최종소비지출|
# |   |총투자|국내 총자본형성 + 국외투자|

# %% [markdown]
# ## 2장 [물가](./2장-물가.html)
#
# |구분|통계명|내용|
# |:---|:---|:---|
# |소비자물가|소비자물가지수|품목성질, 농산물및석유류제외,생활물가지수|
# |수출입물가|수출물가지수|기본분류(농림수산품, 공산품), 특수분류|
# |          |수입물가지수|기본분류(농림수산품, 광산품, 공산품), 용도별(원자료 외)|
# |생산자물가|생산자물가지수|기본분류(상품, 서비스), 특수분류|
# |주택가격 |주택가격지수|매매가격지수, 전세가격지수|
# |토지가격|지가지수|지역별, 용도지역별, 이용상황별 지가변동률|
# |기타|       |국제유가, 기대인플레이션, 환율|

# %% [markdown]
# ## 3장 [노동시장](./3장-노동시장.html)
#
#         - 통계청 경제활동인구조사
#             - 생산가능인구
#             - 경제활동인구
#             - 취업자
#             - 실업자
#             - 비경제활동인구
#             - 고용률
#             - 실업률
#             - 고용보조지표
#                 - 시간관련추가취업가능자
#                 - 잠재취업가능자
#                 - 잠재구직자
#             -  종사상 지위
#                 - 상용근로자
#                 - 임시근로자
#                 - 일용근로자
#                 - 고용원이 있는 자영업자(고용주)
#                 - 고용원이 없는 자영업자(자영자)
#                 - 무급가족종사자
#             - 표준직업분류
#         - 사업체노동력조사
#             - 임금총액(또는 총액임금)
#                 - 정액급여
#                 - 초과급여
#                 - 특별급여
#         - 경제활동인구조사 근로형태별 부가조사
#         - 임금구조기본통계조사
#         - 고용형태별근로실태조사

# %% [markdown]
# ## 4장 [경기](./4장-경기.html)
#
# |구분|통계명|||내용|
# |:---|:---|:---|:---|:---|
# |생산|전산업생산지수|광공업생산지수|산업별| 산업별 광공업생산, 주요산업을 제외한 광공업 생산|
# | | | |공업구조별|경공업, 중공업|
# | | | |기업규모별|대기업, 중소기업|
# | | |서비스업 생산지수|업종별|가중치 기준 상위 8개 업종|
# | | |기타| |농림어업, 건설업, 공공행정|
# |출하 및 재고|생산자제품 출하 및 재고 지수 | | |산업별 출하, 내수출하, 수출출하|
# | |재고율 및 가동률| | |재고율, 제조업평균가동률|
# |경기순환|경기종합지수| | |동행 및 선행지수 순환변동치|
# |기업경기|기업경기실사지수| | |한국은행(수출기업, 내수기업, 대기업, 중소기업), 전경련|

# %% [markdown]
# ## 5장 [금융시장](./5장-금융시장.html)
#
# |구분|통계명|내용|
# |:---|:---|:---|
# | 시장가격 | 금리 | 기준금리, 국고채, 회사채, 금리차 |
# |  | 주가 | 주가지수, 투자자예탁금, 외국인투자, VKOSPI |
# |  | 환율 | 원/달러, 원/100엔 |
# | 자금흐름 | 통화량 | 본원통화, M1, M2, 유동성(Lf), 통화안정증권 |
# |  | 금융기관 수신 | 은행, 자산운용사 수신 |
# |  | 금융기관 여신 | 대기업, 중소기업, 가계대출 <br> CP순발행, 회사채순발행, 주식발행 |
# |  | 가계신용 | 가계대출, 판매신용 |

# %% [markdown]
# ## 6장 [소비](./6장-소비.html)
#
# |구분|통계명|내용|
# |:---|:---|:---|
# | 민간소비 | 국민계정 민간소비 | 민간최종소비지출 및 소비형태별 실질금액, 계절조정금액 |
# | 소매판매 | 소매판매액지수 | 총지수, 경상금액, 내구재(승용차 포함), 준내구재, 비내구재지수 |
# | 소비재생산 출하 및 수입 | 생산, 출하 및 재고 | 소비재생산지수, 생산자제품재고지수, 내수출하지수 |
# |  | 도소매업 | 도소매업생산지수, 소매재고액지수 |
# |  | 소비재 수입 | 해당월 명목금액, 소매재고액지수 |
# | 소비심리 | 소비자동향조사 | 소비자심리지수, 소비지출전망조사, 경제인식 및 전망조사, 가계저축 및 부채조사, 물가전망조사 |
# |  | 기대인플레이션율 | 기대인플레이션율 |

# %% [markdown]
# ## 7장 [설비투자](./7장-설비투자.html)
#
#
# |구분|통계명|내용|
# |:---|:---|:---|
# | 설비투자 | 국민계쩡 설비투자 | 기계류, 운송장비 |
# | 설비투자지수 | 설비투자지수 | 기계류, 운송장비, ICT설비투자지수 |
# |    | 기계류 내수출하 | 기계류, 운송장비, ICT설비투자지수 |
# | 자본재 및 기계류 수입 | 내수용자본재수입액 |  |
# |    | 기계류수입액 | 기계류, 운송장비 |
# | 국내기계수주 | 국내기계수주 | 주체별(공공, 민간), 형태별(기계류, 운송장비) |
# | 설비투자심리 | 한국은행 BSI | 제조업 설비투자 실적/전망 |
# |    | 전경련 BSI | 전산업, 제조업, 비제조업 투자 실적/전망|
# | 설비투자계획 | 주요기업의 설비투자계획조사 | 주요기업의 설비투자 실적 및 계획 |

# %% [markdown]
# ## 8장 [건설투자](./8장-건설투자.html)
#
#
# |구분|통계명|내용|
# |:---|:---|:---|
# | 건설투자 | 국민계정 건설투자 | 지출국민소득측명 건설투자 |
# |  | 국민계정 건설업 | 생산국민소득측면 건설업 |
# | 건설기성 | 건설기성액 | 건설기성 |
# | 건축착공 | 건축착공실적 | 건축착공면적, 주택건설착공실적 |
# | 건설수주 | 건설수주액 | 건설수주액 |
# | 건축허가 | 건축허가면적 | 건축허가면적, 주택건설인허가실적 |
# | 부동산 거래 | 토지 및 아파트 거래 | 토지거래현황, 주택거래현황, 공동주택 분양승인실적, 미분양 주택 |
# | 건설부동산 심리 | 건설업 경기실사지수 | 한국은행 BSI, 건국경제인연합회 BSI, 한국건설산업연구원 CBSI |
# | 주택가격 | 소득 대비 주택가격 비율 (PIR)| KB통계 |
# |          | 주택구입부담지수| 주택금융통계시스템 HUSTAT|

# %% [markdown]
# ## 9장 [지식재산생산물투자](./9장-지식재산생산물투자.html)
#
# |구분|통계명|내용|
# |:---|:---|:---|
# | 지식재산생산물투자 | 국민계정 <br> 지식재산생산물투자| 연구개발(R&D), 기타지식재산생산물투자 |
# | 서비스업생산지수 | 통계청 산업별 서비스업 생산지수 | 전문, 과학 및 기술 서비스업 중 연구개발업 <br> 출판, 영상, 방송통신 및 정보서비스업|

# %% [markdown]
# ## 10장 [대외거래](./10장-대외거래.html)
#
# |구분|통계명|내용|
# |:---|:---|:---|
# | 수출입 |  상품별 수출<br> OECD 선행지수 <br> 세계교역량 <br> 용도별 수입 <br> 지역별 수출입 <br> 무역수지 | 상위 10여개 품목, 일평균 수출액 <br> 주요신흥시장 6개국 선행지수도 함께 제공 <br> CPB 세계교역량지수 <br> 원자재(원유 물량 및 단가, 유가), 자본재, 소비재 <br> 중국, 미국, 일본, ASEAN, EU, 중동, 중남미   |
# | 무역지수 및 교역조건 | 무역지수 <br> 교역조건|  수출입물량지수, 수출입금액지수, 수출입물가지수<br>순상품교역조건지수, 소득교역조건지수  |
# | 국제수지 | 경상수지 | 상품수지, 서비스수지, 본원이전소득수지 |
# |  | 자본금융계정 | 자본계정, 금융계정, 외환보유액, 외채 |

# %% [markdown]
# ## 11장 [재정](./11장-재정.html)
