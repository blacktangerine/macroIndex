# %% [markdown]
# [ 뒤로](./index.html)

# %% [markdown]
# # 11장 재정

# %% [markdown]
# ## 1. 개요
#
# - 정부는 조새수입긍을 주요 재원으로 하여 공공서비스, 경제개발, 사회복지 등을 제공하기 위해 지출활동을 하는데, 이러한 정부의 재원조달 및 지출활동을 재정이라고 함
# - 재정의 기능
#     - 자원의 효율적 배분: 시장경제 기능만으로 효율적인 자원배분을 기대하기 어려운 경우, 정부가 공공재 공급, 보조금 지급 등을 통해 자원 배분에 개입하여 시장기능을 보완
#     - 소득재분배: 정부가 세입측면에서는 누진세율 적용, 세출 측면에서는 사회보장제도, 저소득층 주택공급 등 재정을 통해 소득 재분배 기능을 수행
#     - 경제안정화:정부는 통화금융정책과 함께 거시경제정책의 중요한 수단의 하나로써 재정정책을 이용하여 경제안정화를 도모
#
# - 우리나라의 재정 현황을 파악하고 정책방향을 제시하기 위해 재정수입과 지출을 기록한 통합재정과 국가채무 관련 지표를 활용
#     - 통합재정을 통해 재정수입과 지출 내역을 확인하고 국가 전체의 재정규모와 수지를 파악
#     - 국가 채무는 구가가 채무자로서 차후에 상환해야 하는 금액으로 중앙정부 이외에 지방정부, 보증채무도 함께 점검
#     - 통합재정과 국가채무는 재정건전성을 파악하고 향후 재정운용에 대한 방향을 제시하는데 유용한 지표
#
# *[표 11-1] 재정 부문 주요 통계지표**
# <center>
#
# |구분|통계명|내용|
# |:---|:---|:---|
# | 재정 | 수입총량 | 경상수입, 자본수입, 보전수입, 내부거래 수입, 융자회수 |
# |     | 지출총량 | 경상지출, 자본지출, 보전지출, 내부거래 지출, 융자지출 |
# |     | 통합재정수지 | 일반회계, 특별회계, 세입세출외, 비금융성기금, 기업특별회계 |
# |     | 관리재정수지 | 통합재정수지 - 사회보장성기금수지 |
# | 국가채무 | 중앙정부 | 국채, 차입금, 국고채무부담행위 |
# |         | 지방정부 |  |
# |         | 보증채무 |  |

# %% [markdown]
# ## 2. 통합재정(Consolidated Public Sector Finance)
#
# **(정의)**
# - 우리나라 통합재정은 중앙정부와 지방정부의 통합재정으로 구성
#     - 중앙정부 통합재정은 2022년 기준 일반회계(1개), 기타특별회계(15개), 기업특별회계(5개), 기금(68개)로 구성
#     - 지방정부 통합재정도 일반회계, 특별회계(지방공기업특별회계+기타특별회계), 기금으로 구성
# - 통합재정상 수입과 지출은 통상적인 정부회계상의 수입$\cdot$지출과는 상이한 개념
#     - 정부회계상의 수입은 회계년도 내의 재정수입을 비롯한 보전재원이나 내부거래 등이 모두 해당되고, 지출도 차입금 상환등 보전지출이나 내부거래 지출도 포함
#     - 그러나, 통합재정에서는 정부의 수입을 세입, 보전수입 및 융자회수로 분류하고 지출은 제출, 보전지출 및 융자지출로 구분
#         - 세입$\cdot$세출 중 기업특별회계 영업수입(지출)은 기특영업수지로 합산하여 수입 또는 지출에 반영
#
#
# *[표 11-2] 통합재정 수입과 지출**
# <center>
#
# |구분|통계명|내용|
# |:---|:---|:---|
# | 통합재정수입 | 경상수입 | 조세수입, 세외수입, 사회보장기여금 등 |
# |   | 자본수입 | 고정자산매각 수입 등 |
# | 통합재정지출 | 경상지출 | 재화및용역, 이자지급, 보조금 및 경상이전 등 |
# |  | 자본지출 | 고정자산취득, 재고자산매입 등 |
# | 기타 | 보전거래 | 국내해외보전거래, 내부거래 등 |
# |  | 융자거래 | 융자금$\cdot$출자금 회수 및 지출 |

# %% [markdown]
# - 중앙정부 통합재정수지를 구성하는 통합재정 수입과 통합재정지출 및 순융자 항목을 중심으로 분석
#
# - 우리나라늬 재정지표 개념은 재정총량, 총수입(지출), 통합재정수입(지출)로 구분
#     - 재정총량은 중앙정부의 재정거래 전체 금액을 나타내는 지표로 일반 지출 뿐만 아니라 보전거래 및 내부거래를 포함
#     - 총수입 및 총지출은 정부의 분야별(복지, 경제, 국방 등) 재정지출 규모를 국민들이 이해하기 쉽게 도입한 개념으로 총계에서 보전거래 및 내부거래를 제외하여 산출
#         - 총수입(지출) = 재정총량 - 보전거래 - 내부거래
#     - 통합재정수입(지출)은 총수입(지출)에서 융자회수(지출) 및 기업특별회계 영업수입(지출)을 제외한 후, 기업특별회계 영업수지 흑자는 통합재정수입으로, 적자는 통합재정지출로 반영
#         - 기업특별회계 영업부문은 순수한 재정활동이 아니므로 통합재정에서는 영업수입과 영업지출의 차이만 재정규모에 포함
#
# ### 2.1 통합재정수입
#
# **(정의 및 지표작성)**
#
# - 통합재정상의 수입은 총수입 중 차입금, 국채발행수입 등 채무성 수입인 보전거래 수입과 기타회계 전입금 등 내부거래 수입을 제외한 순수입으로 정의하며 경상수입과 자본수입으로 분류
#     - 경상수입은 각 회계연도의 조세수입과 사회보장기여금, 세외수입으로 구성
#         - 조세수입은 소득세 및 법인세, 재산세, 재화와 용역세, 관세, 기타 조세로 구성
#         - 세외수입은 임대료, 이자수입, 수수료, 벌금 및 공무원연기김 등으로 구성
#     - 자본수입은 생산과정에서 1년 이상 사용할 수 있는 비금융자산의 매각거래로부터 발생한 수입금을 뜻함.
#         - 자본수입은 고정자산매각, 재고자산매각, 토지 및 무형자산매각 및 국내자본 해외자본이전수입으로 구성
#     - 지표 작성시 경상수입과 자본수입을 항목별로 분류하여 명목GDP 대비 비율도 함계 계산
#
# **(출처 및 공표일시)**
#
# - 기획재정부에서는 통합재정수입통계를 매월 발표하고 있으며, 기획재정부 보도자료와 통계청 국가통계포털을 통해 확인 가능
#     - 기획재정부 보도자료는 주로 해당월 종료 후 60일 이내에 발표되며, 발표가 지연될 시에는 기획재정부 재정건전성관리과에 확인
#         - 기획재정부 보도자료 경로: https://www.moef.go.kr/ --- 통계 --- 재정통계 --- 통합재정수지 안내
#         - 통계청 경로: https://kosis.kr/index/index.do ---주제별통계 --- 정부$\cdot$재정 --- 재정 --- 통합재정수지
#
# **[그림 11-1] 기획재정부 통합재정수지**
# <p align="center">
# <img src = "기재부통합재정.png" width = "75%" height = "75%">
# </p>
#
#
# **[그림 11-2] 통계청 통합재정수지**
# <p align="center">
# <img src = "통계청통합재정.png" width = "75%" height = "75%">
# </p>
#
# **(조사주기 및 자료의 형태)**
#
# - 기획재정부는 2005년 이후의 월별 누적자료를(원계열)을 보도자료로 발표하고 있음.
#     - 기획재정부 통합재정수지 보도자료에서 통합재정수입 포괄범위(일반회계, 특별회계 등)에 따라 경상수입과자본수입의 월별 누적 금액을 확인
#     - 한편, 통계청 통합수지에서도 1999년 12월 이후 월간자료를 십억원 단위로 확인가능
#
#
# ### 2.2 통합재정지출 및 순융자
#
# **(정의 및 지표작성)**
#
# - 통합재정상의 지출은 총지출 중 채무상환, 예탁금 등 보전거래 지출과 타 회계로의 전출금 등 내부거래 지출을 제외한 순지출을 의미하며, 경상지출과 자본지출로 분류
#     - 경상지출은 각 회계연도에 연속적으로 반복하여 지출되는 일정 경비로 재화와 용역, 이자지급, 보조금 및 경상이전, 기업특별회계 경상지출로 구성
#     - 자본지출은 생산과정에서 1년 이상 사용할 수 있는 비금융자산의 매입거래로부터 발생한 지출금으로 정의
#         - 자본지출은 고정자산취득, 재고자산매입, 토지 및 무형자산매입 및 자본이전 등으로 구성
#     -순융자는 융자지출에서 융자회수를 차감하여 계산
#         - 융자지출 및 회수는 유동성 목적이 아닌 정책적 목적의 대출 및 대출금회수(출자도 포함)를 의미
#         - 융자지출은 민간에 대한 융자와 출자, 융자회수는 민간으로부터의 융자회수금 및 출자회수금으로 구성
#
# **(출처 및 공표일시)**
#
# - 통합재정지출과 순융자 자료는 기획재정부와 통계청에서 제공하고 있으며, 자세한 결로는 통합재정 수입의 출저와 동일
#
# **(조사주기 및 자료의 형태)**
#
# -  통합재정수입과 모두 동일
#
# ### 2.3 통합재정수지 및 관리재정수지
#
# #### 2.3.1 통합재정수지
#
# **(정의 및 지표작성)**
#
# - 당해년도의 순수한 수입과 지출의 차이를 뜻하며, 통합재정수입에서 통합재정지출 및 순융자를 차감한 금액을 의미
#     - 통합재정수지는 독립적인 회계$\cdot$기금의 수지 차이를 각각 집계하여 합한 것으로, 각 회계$\cdot$기금은 설치목적에 따라 독립적으로 수입$\cdot$지출이 이루어지기 떄문에 특정회계$\cdot$기금의 흑자를 타 회게$\cdot$기금이 사용할 수 없음.
#     - 통합재정수지 = 순수재정수입 - 순수재정지출 = (세입+융자회수)-(세출+융자지출) = 세입 - 세출 + 순융자
#
# **(해석)**
#
# - 통합재정수지는 정부의 재정규모를 파악하고 국가재정이 실물경제에 미치는 효과와 국가간의 비교를 위해 활용
#     - 재정규모는 정부부문의 예산서 및 기금운용계획상의 총지출 규모에서 채무상환 등을 차감한 순수한 재정활동 규모를 뜻함
#     -  통합재정 자료를 통해 정부부문의 소비와 저축, 투자 등을 추정
#         - 정부의 경상지출과 경상수입으로 정부소비와 정부저축의 규모를 파악하고 자본지출과 자본수입을 통해 정부투자를 점검하여 재정활동이 총수요와 국민경제 전반에 미치는 영향을 분석
#     - 한편, IMF 가맹국은 동일한 기준에 의해 재정구모와 재정수지를 작성하므로 국제적 비교도 가능
#         - 특히, GDP대비 재정수지는 국가 간 비교에 자주 사용
#
# **(출처 및 공표일시)**
#
# - 통합재정수지 자료는 기획재정부와 통계청에서 제공하고 있으며, 자세한 경로는 통합재정수입의 출처와 동일
#
#
# #### 2.3.2 관리재정수지
#
# **(정의 및 지표작성)**
#
# - 통합재정수지에서 사회보장성기금과 공적자금손실분의 국채전환 등을 제외한 것으로, 실질적인 재정운용 결과의 판단지표로 활용되며 재정건전성을 정확히 판단하는데 유용
#     - 사회보장성기금은 사회보장급여를 목적으로 정부가 통제하며, 국민연금, 사립학교교직원연금, 산업재해보상보험 및 예방기금, 고용보험기금으로 구성
#         - 사회보장성기금수지는 국민들이 낸 총 보험료에서 국민들에게 지급한 총 급여를 제외한 것
#     - 공적자금손실분의 국채전환은 과거 금융구조조정에 필요한 자금을 조성하기 위해 발행한 예금보험상환기금채권 중 정부가 보증한 부분이 국채로 전환되며 발생
#
# **(해석)**
#
# - 관리재정수지는 정부의 재정정책에 따른 순수한 수입과 지출의 차이로 정부의 재정정책기조, 재정건전성 등을 판단하는 핵심지표
#
# **(출처 및 공표일시)**
#
# - 관리재정수지 자료는 기획재정부와 통계청에서 제공하고 있으며, 자세한 경로는 통합재정수입의 출처와 동일
#
# #### 2.3.3 재정집행관리
#
# **(정의 및 지표작성)**
#
# - 기획재정부에서는 주요 관리대상사업에 대해 재정집행관리제도를 시행함으로써 재정의 경기대응 기능을 강화하고 예산집행의 효율성을 제고
#     - 기획재정부는 재정관리점검회의를 통해 경기상황과 재정여건 등을 고려하여 연간 및 분기별 재정집행계획을 수립하고 지속적으로 관리
#     -주요 관리대상사업에 대한 집행계획을 수립하고, 매우러 예산 및 기금, 공공기관의 재정집행실적에 대해 연간계획 대비 집행실적을 발표
#         - 단위사업별 집행실적은 사업비가 500억원 이상의 사업에 대해서만 발표
#
# **(해석)**
#
# - 주요 관리대상사업의 집행계획 및 실적은 정부의 재정정책기조를 파악하는 한편, 분야별 재정집행 실적을 통해 효율적 재정운용을 위한 정책적 시사점을 파악하는데 활용
#
# **(출처 및 공표일시)**
#
# - 기획재정부에서는 주요 관리대상사업 재정집행실적 통계를 매월 발표하고 있으며, 기획재정부 보도자료와 재정정보 공개시스템을 통해서도 확인 가능
#     - 기획재정부에서는 매월 10일경에 주요 관리대상사업 집행실적 및 주요 단위사업별 집행실적을 각각 발표
#         - 기획재정부 보도자료 경로: https://www.moef.go.kr/ --- 정책 --- 정책자료 --- 발간물 --- 월간재정동향 ()
#         - 재정정보 공개시스템 경로: https://www.openfiscaldata.go.kr/ --- 재정연구분석 ---재정분석통계 ---중앙정부 --- 상세재정통계 --- 집행 --- 집행실적 --- 소관별집행실적, 공공기관별 집행실적
#
#
# **[그림 11-3] 기획재정부 월간재정동향**
# <p align="center">
# <img src = "월간재정동향.png" width = "75%" height = "75%">
# </p>
#
#
# **[그림 11-4] 열린재정(재정정보 공개시스템) 주요관리대상사업 집행실적**
# <p align="center">
# <img src = "재정정보공개시스템.png" width = "75%" height = "75%">
# </p>

# %% [markdown]
# ## 3. 국가채무(Government Debt)
#
# **(정의 및 지표작성)**
#
# - 국가채무는 국가재정법상 국가의 회계 또는 기금이 부담하는 금전 채무
#     - 국가의 회계 또는 기금은 중앙관서의 장이 관리$\cdot$운용하는 회계와 기금을 의미하고, 금전채무는 국가의 회계 및 기금이 발행한 채권$\cdot$차입금$\cdot$국고채무부담행위와 국가보증채무 중 정부의 대지급 이행이 확정된 채무를 뜻함.
#     - 정부는 중장기 '국가채무관리계획'을 수립하고 결산 후 '국가채무관리보고서'를 작성하는데, 이때 국가채무는 중앙정부의 채무로 차입형태에 따라 국채, 차입금, 국고채부담행위로 구분
#         - 국채는 재정수지상 세입부족액을 보전하고 정책집행 등에 필요한 재원을 조달하기 위하여 국가가 발행하는 채권을 의미하며, 국고채권, 국민주택채권, 외와표시 외국환평형기금채권 등이 발행됨
#         - 차입금은 정부가 한국은행, 민간기금 또는 국제기구, 외국정부 등으로부터 차입하는 자금을 의미하며, 법정유가증권의 발행 없이 조달한다는 점에서 국채와 구별되고 차입대상에 따라 국내차입금과 해외차입금으로 구분
#         - 국고채무부담행위는 국가가 법률에 따른 것과 세출예산 금액 또는 계속비 총액의 범위 안의 것 외에 채무를 부담하는 행위를 의미하며, 사전에 국회의 의결을 받은 범위 내에서만 가능
#     - 보증채무는 국가각 지급을 보증한 채무를 뜻하며 사정에 국회의 동의를 얻어야 함.
#         - 보증채무는 국가재정법상 국가채무에 포함되지는 않지만, 원채무자의 상환능력이 없는경우 국민의 재정 부담을 초래할 수 있어 국가채무와 함께 작성하고 있음.
#
# **(해석)**
#
# - 국가채무는 미래 정부가 채무자로서 상환해야하는 금액을 의미하며, 중장기 재정 건전성을 보여주는 핵심지표
#     - 우리나라 국가채무의 규모와 추세 등을 분석하는 것은 매우 중요
#     - 이와 함께 국가 간 비교를 통해 우리나라 재정 상황을 확인하고 향후 국가재정 운용방향에 참고
#
# **(출처 및 공표일시)**
#
# - 매년 4월 기획재정부의 '국가결산 결과'를 통해 중앙정부와 지방정부의 채무 규모를 파악하고 국회심사를 통해 확정
#     - 4월에 발표되는 '국가결산 결과'는 감사원의 검사를 거친 후 5월말경 국회에 제출
#     - 6월 초에 재정정보 공개시스템(열린재정)의 '국가채무관리보고서'를 통해 국가 채무자료를 확인할 수 있음.
#         - 통계청 경로: https://kosis.kr/index/index.do --- 국가주요지표(e-나라지표, https://www.index.go.kr/unity/potal/eNara/main/EnaraMain.do) --- 국가채무추이(https://www.index.go.kr/unity/potal/main/EachDtlPageDetail.do?idx_cd=1106)
#         - 재정정보 공개시스템 경로: https://www.openfiscaldata.go.kr/ --- 재정연구분석 --- 재정분석통계 --- 중앙정부 --- 국가채무 --- 국가채무(D1)
#         - 결산 및 보고서 경로: https://www.openfiscaldata.go.kr/ --- 재정연구분석 ---재정자료실 --- 재정보고서$\cdot$문서 --- 국가채무관리보고서
#
#
# **[그림 11-5] 통계청 국가채무**
# <p align="center">
# <img src = "통계청국가채무.png" width = "75%" height = "75%">
# </p>
#
#
# **[그림 11-6] 열린재정(재정정보 공개시스템) 국가채무**
# <p align="center">
# <img src = "열린재정국가채무.png" width = "75%" height = "75%">
# </p>
#
# **[그림 11-6] 열린재정 국가채무관리보고서**
# <p align="center">
# <img src = "국가채무관리보고서.png" width = "75%" height = "75%">
# </p>

# %% [markdown]
# [ 뒤로](./index.html)
